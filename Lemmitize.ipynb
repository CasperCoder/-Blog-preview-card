# %% [markdown]
# <a href="https://colab.research.google.com/github/CasperCoder/-Blog-preview-card/blob/main/Lemmitize.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
connect_tokens = ['connecting', 'connected', 'connectivity', 'connect', 'connects']

# %%
learn_tokens = ['learning', 'learns', 'learn', 'learned', 'learner', 'learners']

# %%
likes_tokens = ['likes', 'better', 'worse']

# %% [markdown]
# ## **Stemming**

# %%
import nltk
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
for t in connect_tokens:
  print(t, ": ", ps.stem(t))
# Out:
# connecting :  connect
# connected :  connect
# connectivity :  connect
# connect :  connect
# connects :  connect

# %%
for t in learn_tokens:
  print(t, ": ", ps.stem(t))
# Out:
# learning :  learn
# learns :  learn
# learn :  learn
# learned :  learn
# learner :  learner
# learners :  learner

# %%
for t in likes_tokens:
  print(t, ": ", ps.stem(t))
# Out:
# likes :  like
# better :  better
# worse :  wors

# %% [markdown]
# ##Lemmatization

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
lemmatizer = WordNetLemmatizer()

# %%
for t in connect_tokens:
  print(t, ": ", lemmatizer.lemmatize(t))
# Out:
# connecting :  connecting
# connected :  connected
# connectivity :  connectivity
# connect :  connect
# connects :  connects

# %%
for t in learn_tokens:
  print(t, ": ", lemmatizer.lemmatize(t))
# Out:
# learning :  learning
# learns :  learns
# learn :  learn
# learned :  learned
# learner :  learner
# learners :  learner

# %%
for t in likes_tokens:
  print(t, ": ", lemmatizer.lemmatize(t))
# Out:
# likes :  like
# better :  better
# worse :  worse
